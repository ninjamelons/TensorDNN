# %% [markdown]
# <a href="https://colab.research.google.com/github/ninjamelons/TensorDNN/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import os

import numpy as np
import pandas as pd
import json
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Activation, LSTM, Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
tf.__version__
# Out:
# '1.13.1'

# %%
max_words = 50000
max_len = 350
embedding_dim = 100
lstm_out = 100

# %%
from google.colab import files

print("Main data:")
uploaded = files.upload()
# Out:
# Main data:
#      <input type="file" id="files-b751e6c6-e043-4e4e-9384-16d773ffa2e4" name="files[]" multiple disabled />
#      <output id="result-b751e6c6-e043-4e4e-9384-16d773ffa2e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving batched3.json to batched3.json

# %%
#openfile=open('batched3.json')
#jsondata=json.load(openfile)
df_source=pd.read_json('batched3.json', lines=True)
#openfile.close()
#df_source['categories'] = df_source['categories'].apply(lambda x: x[0])

# %%
target_count = df_source.categories.value_counts()
for t in target_count:
  print(t)

target_count.plot(kind='bar', title='Count (catgories)');
# Out:
# 8847
# 8556
# 6276
# 5279
# 5000
# 1156

# %%
df_source=df_source.drop((df_source.sample(79, random_state=200).index))

# %%
#count_class_0, count_class_1, count_class_2 = df_source.categories.value_counts()
#df_class_0 = df_source[df_source['categories']=='News']
#df_class_1 = df_source[df_source['categories']=='Twitter']
#df_class_2 = df_source[df_source['categories']=='Reddit']

#df_class_0_under = df_class_0.sample(count_class_2, random_state=1000)
#df_class_1_under = df_class_1.sample(count_class_2, random_state=1000)

#df_balanced = pd.concat([df_class_0_under, df_class_1_under, df_class_2],
#                        axis=0)

#df_balanced.categories.value_counts().plot(kind='bar');

# %%
#df_balanced = df_balanced.sort_index()
#df_balanced

# %%
### If it borks alternate the commends so you are getting df_source data

#text = df_balanced['text'].values
text = df_source['text'].values
#y = df_balanced['categories'].values
y = df_source['categories'].values

sentences_train, sentences_test_val, categories_train, categories_test_val = train_test_split(text, y, test_size=0.30, random_state=1000)
sentences_test, sentences_validation, categories_test, categories_validation = train_test_split(sentences_test_val, categories_test_val, test_size=0.25, random_state=1000)

# %%
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(sentences_train)
label_encoder = LabelEncoder()
onehot_encoder = OneHotEncoder(sparse=False)

X_train = tokenizer.texts_to_sequences(sentences_train)

integer_encoded_categories_train = label_encoder.fit_transform(categories_train)
integer_encoded_categories_train = integer_encoded_categories_train.reshape(len(integer_encoded_categories_train), 1)
y_train = onehot_encoder.fit_transform(integer_encoded_categories_train)


X_test = tokenizer.texts_to_sequences(sentences_test)

integer_encoded_categories_test = label_encoder.fit_transform(categories_test)
integer_encoded_categories_test = integer_encoded_categories_test.reshape(len(integer_encoded_categories_test), 1)
y_test = onehot_encoder.fit_transform(integer_encoded_categories_test)


X_validation = tokenizer.texts_to_sequences(sentences_validation)

integer_encoded_categories_validation = label_encoder.fit_transform(categories_validation)
integer_encoded_categories_validation = integer_encoded_categories_validation.reshape(len(integer_encoded_categories_validation), 1)
y_validation = onehot_encoder.fit_transform(integer_encoded_categories_validation)

vocab_size = len(tokenizer.word_index) + 1

X_train = pad_sequences(X_train, padding='post', maxlen=max_len)
X_test = pad_sequences(X_test, padding='post', maxlen=max_len)
X_validation = pad_sequences(X_validation, padding='post', maxlen=max_len)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
print(X_train.shape, X_test.shape, X_validation.shape)
print(y_train.shape, y_test.shape, y_validation.shape)
# Out:
# (24524, 350) (7883, 350) (2628, 350)
# (24524, 6) (7883, 6) (2628, 6)

# %%
#X_train = tf.keras.utils.normalize(X_train, axis=1)
#X_test = tf.keras.utils.normalize(X_test, axis=1)
#X_validation = tf.keras.utils.normalize(X_validation, axis=1)

# %%
from sklearn.utils import compute_class_weight
class_weight = compute_class_weight('balanced', np.unique(categories_train), categories_train) 
class_weight = dict(enumerate(class_weight))

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
def plot_history_one_graph(history):
    
    i = 0
    plt.figure(figsize=(12, 5))
    for h in history:
      i +=1
      acc = h.history['acc']
      val_acc = h.history['val_acc']
      loss = h.history['loss']
      val_loss = h.history['val_loss']
      x = range(1, len(acc) + 1)
      plt.subplot(2, 2, 1)
      plt.title('Training accuracy')
      plt.plot(x, acc, label= h.model.name)
      plt.legend()
      plt.subplot(2, 2, 2)
      plt.title('Validation accuracy')
      plt.plot(x, val_acc, label= h.model.name)
      plt.legend()
      plt.subplot(2, 2, 3)
      plt.title('Training loss')
      plt.plot(x, loss, label= h.model.name)
      plt.legend()
      plt.subplot(2, 2, 4)
      plt.title('Validation loss')
      plt.plot(x, val_loss, label= h.model.name)
      plt.subplots_adjust(top=1.5)
      plt.legend()

# %%
tf.keras.backend.clear_session()

model_1 = Sequential(name="CNN")
model_1.add(tf.keras.layers.Embedding(input_dim=vocab_size,
                                    output_dim=embedding_dim,
                                    input_length=max_len))
model_1.add(tf.keras.layers.Conv1D(32, 2, activation='relu', padding='same'))
model_1.add(tf.keras.layers.Conv1D(32, 3, activation='relu'))
model_1.add(tf.keras.layers.MaxPool1D(pool_size=2))
model_1.add(tf.keras.layers.Dropout(0.25))

model_1.add(tf.keras.layers.Conv1D(64, 3, activation='relu', padding='same'))
model_1.add(tf.keras.layers.Conv1D(64, 3, activation='relu'))
model_1.add(tf.keras.layers.MaxPool1D(pool_size=2))
model_1.add(tf.keras.layers.Dropout(0.25))

model_1.add(tf.keras.layers.Flatten())
model_1.add(tf.keras.layers.Dense(128, activation='relu'))
model_1.add(tf.keras.layers.Dense(6, activation='softmax'))
model_1.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])
model_1.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 350, 100)          16163700
# _________________________________________________________________
# conv1d (Conv1D)              (None, 350, 32)           6432
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 348, 32)           3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 174, 32)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 174, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 174, 64)           6208
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 172, 64)           12352
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 86, 64)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 86, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 5504)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               704640
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 16,897,210
# Trainable params: 16,897,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
# This address identifies the TPU we'll use when configuring TensorFlow.
TPU_WORKER_1 = 'grpc://' + os.environ['COLAB_TPU_ADDR']
tf.logging.set_verbosity(tf.logging.INFO)
tpu_model_1 = tf.contrib.tpu.keras_to_tpu_model(
    model_1,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(TPU_WORKER_1)))
tpu_model_1.summary()
# Out:
# INFO:tensorflow:Querying Tensorflow master (grpc://10.58.52.226:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 163210747117398496)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 5905865573252813668)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 472016348054502842)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 8854384023449538565)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 6493743533975228688)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 10786899567657318559)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 10367415288657682752)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 597364814785073352)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 16117282752463516890)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 10929019859124950901)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 6691775897138489461)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_input (InputLayer) (None, 350)               0
# _________________________________________________________________
# embedding (Embedding)        (None, 350, 100)          16163700
# _________________________________________________________________
# conv1d (Conv1D)              (None, 350, 32)           6432
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 348, 32)           3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 174, 32)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 174, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 174, 64)           6208
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 172, 64)           12352
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 86, 64)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 86, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 5504)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               704640
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 16,897,210
# Trainable params: 16,897,210
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = time.time()
history_1 = tpu_model_1.fit(X_train, y_train,
                        batch_size=512,
                        epochs=30,
                        class_weight=class_weight,
                        validation_data=(X_test, y_test))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Train on 24524 samples, validate on 7883 samples
# Epoch 1/30
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(64,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(64, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(64, 6), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f295702fa20> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 5.907196521759033 secs
# INFO:tensorflow:Setting weights on TPU model.
# INFO:tensorflow:CPU -> TPU lr: 0.0010000000474974513 {0.001}
# INFO:tensorflow:CPU -> TPU beta_1: 0.8999999761581421 {0.9}
# INFO:tensorflow:CPU -> TPU beta_2: 0.9990000128746033 {0.999}
# INFO:tensorflow:CPU -> TPU decay: 0.0 {0.0}
# WARNING:tensorflow:Cannot update non-variable config: epsilon
# WARNING:tensorflow:Cannot update non-variable config: amsgrad
# 23552/24524 [===========================>..] - ETA: 0s - loss: 1.1396 - acc: 0.5054INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(57,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(57, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(57, 6), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f295702fa20> [<tf.Variable 'tpu_139815701510464/Adam/iterations:0' shape=() dtype=int64>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295b176da0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295b1b7320>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295b1b7ef0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295af180f0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295af21588>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295af38588>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295ace0278>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295c6dab00>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295c4f2358>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295a945278>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295a7cec50>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295c48cf60>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295c5f4c18>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295c6734a8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f296b02add8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2961c474e0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2967fd2668>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2968a019e8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295c830a20>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295c4f33c8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295c82d278>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295ad6b978>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295ad5e748>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295af0cd30>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295adb6748>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295aedeef0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295abc03c8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295b36c0b8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295b39c2b0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295c4e4d30>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295b0c61d0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295b472128>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295aa6b4a8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295a982908>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295a822860>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295a85c048>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295a8ef978>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x ...
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 6.041083812713623 secs
# 24064/24524 [============================>.] - ETA: 0s - loss: 1.1305 - acc: 0.5098INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(64,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(64, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(64, 6), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f2954e3b860> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 2.921222686767578 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(25,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(25, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(25, 6), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f2954e3b860> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 3.5910816192626953 secs
# 24524/24524 [==============================] - 43s 2ms/sample - loss: 1.1224 - acc: 0.5128 - val_loss: 0.9908 - val_acc: 0.5669
# Epoch 2/30
# 24524/24524 [==============================] - 6s 261us/sample - loss: 0.6511 - acc: 0.7492 - val_loss: 1.2627 - val_acc: 0.5522
# Epoch 3/30
# 24524/24524 [==============================] - 6s 262us/sample - loss: 0.5001 - acc: 0.8175 - val_loss: 1.3903 - val_acc: 0.6400
# Epoch 4/30
# 24524/24524 [==============================] - 6s 263us/sample - loss: 0.3742 - acc: 0.8664 - val_loss: 1.9198 - val_acc: 0.6192
# Epoch 5/30
# 24524/24524 [==============================] - 6s 264us/sample - loss: 0.3527 - acc: 0.8821 - val_loss: 1.5267 - val_acc: 0.6650
# Epoch 6/30
# 24524/24524 [==============================] - 6s 259us/sample - loss: 0.2993 - acc: 0.8954 - val_loss: 1.1195 - val_acc: 0.7032
# 24524/24524 [==============================] - 6s 259us/sample - loss: 0.0215 - acc: 0.9905 - val_loss: 1.5606 - val_acc: 0.7569
# Epoch 27/30
# 24524/24524 [==============================] - 6s 262us/sample - loss: 0.0201 - acc: 0.9909 - val_loss: 1.5919 - val_acc: 0.7490
# Epoch 28/30
# 24524/24524 [==============================] - 6s 263us/sample - loss: 0.0197 - acc: 0.9907 - val_loss: 1.6178 - val_acc: 0.7547
# Epoch 29/30
# 24524/24524 [==============================] - 6s 263us/sample - loss: 0.0207 - acc: 0.9901 - val_loss: 1.6344 - val_acc: 0.7574
# Epoch 30/30
# 24524/24524 [==============================] - 6s 262us/sample - loss: 0.0195 - acc: 0.9905 - val_loss: 1.6780 - val_acc: 0.7537
# --- 229.91678881645203 seconds ---

# %%
loss, accuracy = tpu_model_1.evaluate(X_train, y_train)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = tpu_model_1.evaluate(X_test, y_test)
print("Testing Accuracy: {:.4f}".format(accuracy))
# Out:
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(4, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(4, 6), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f2954e3b860> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 3.4661169052124023 secs
# 24512/24524 [============================>.] - ETA: 0s - loss: 0.0154 - acc: 0.9925INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(1,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(1, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(1, 6), dtype=tf.float32, name='dense_1_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f2954e3b860> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 2.809070348739624 secs
# 24524/24524 [==============================] - 21s 854us/sample - loss: 0.0154 - acc: 0.9925
# Training Accuracy: 0.9925
# 7883/7883 [==============================] - 5s 573us/sample - loss: 1.6774 - acc: 0.7537
# Testing Accuracy: 0.7537

# %%
tf.keras.backend.clear_session()
model_3 = Sequential(name="RNN(GRU)")
model_3.add(tf.keras.layers.Embedding(input_dim=vocab_size,
                                    output_dim=embedding_dim,
                                    input_length=max_len))
model_3.add(tf.keras.layers.GRU(lstm_out))
model_3.add(tf.keras.layers.Dense(6, activation='softmax'))
model_3.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])
model_3.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 350, 100)          16163700
# _________________________________________________________________
# gru (GRU)                    (None, 100)               60300
# _________________________________________________________________
# dense (Dense)                (None, 6)                 606
# =================================================================
# Total params: 16,224,606
# Trainable params: 16,224,606
# Non-trainable params: 0
# _________________________________________________________________

# %%
tpu_model_3 = tf.contrib.tpu.keras_to_tpu_model(
    model_3,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(TPU_WORKER)))
tpu_model_3.summary()
# Out:
# INFO:tensorflow:Querying Tensorflow master (grpc://10.58.52.226:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 163210747117398496)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 5905865573252813668)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 472016348054502842)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 8854384023449538565)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 6493743533975228688)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 10786899567657318559)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 10367415288657682752)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 597364814785073352)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 16117282752463516890)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 10929019859124950901)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 6691775897138489461)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_input (InputLayer) (None, 350)               0
# _________________________________________________________________
# embedding (Embedding)        (None, 350, 100)          16163700
# _________________________________________________________________
# gru (GRU)                    (None, 100)               60300
# _________________________________________________________________
# dense (Dense)                (None, 6)                 606
# =================================================================
# Total params: 16,224,606
# Trainable params: 16,224,606
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = time.time()
history_3 = tpu_model_3.fit(X_train, y_train,
                        batch_size=512,
                        epochs=30,
                        class_weight=class_weight,
                        validation_data=(X_test, y_test))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Train on 24524 samples, validate on 7883 samples
# Epoch 1/30
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(64,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(64, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(64, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f295426e390> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 4.635220527648926 secs
# INFO:tensorflow:Setting weights on TPU model.
# INFO:tensorflow:CPU -> TPU lr: 0.0010000000474974513 {0.001}
# INFO:tensorflow:CPU -> TPU beta_1: 0.8999999761581421 {0.9}
# INFO:tensorflow:CPU -> TPU beta_2: 0.9990000128746033 {0.999}
# INFO:tensorflow:CPU -> TPU decay: 0.0 {0.0}
# WARNING:tensorflow:Cannot update non-variable config: epsilon
# WARNING:tensorflow:Cannot update non-variable config: amsgrad
# 23552/24524 [===========================>..] - ETA: 0s - loss: 1.5268 - acc: 0.3808INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(57,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(57, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(57, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f295426e390> [<tf.Variable 'tpu_139815771470648/Adam/iterations:0' shape=() dtype=int64>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f29532f3240>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f29532f3d68>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2953291b38>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f29532544e0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295321e2b0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295321ee48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f29531b6d68>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f295317ee10>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f29530ef0f0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f29530ba4a8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f29530268d0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2953004898>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2952fcc4a8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2952f617b8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2952efa978>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2952e44c88>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2952e6b7f0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f2952e34c88>]
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 7.062376499176025 secs
# 24064/24524 [============================>.] - ETA: 0s - loss: 1.5225 - acc: 0.3827INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(64,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(64, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(64, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f29514f0dd8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 6.356785535812378 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(25,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(25, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(25, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f29514f0dd8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 6.549647569656372 secs
# 24524/24524 [==============================] - 57s 2ms/sample - loss: 1.5190 - acc: 0.3840 - val_loss: 1.3090 - val_acc: 0.4646
# Epoch 2/30
# 24524/24524 [==============================] - 8s 310us/sample - loss: 1.1851 - acc: 0.4953 - val_loss: 1.0678 - val_acc: 0.4853
# Epoch 3/30
# 24524/24524 [==============================] - 8s 308us/sample - loss: 0.9160 - acc: 0.6145 - val_loss: 1.0835 - val_acc: 0.5631
# Epoch 4/30
# 24524/24524 [==============================] - 7s 304us/sample - loss: 0.6605 - acc: 0.7477 - val_loss: 0.9084 - val_acc: 0.6415
# Epoch 5/30
# 24524/24524 [==============================] - 8s 306us/sample - loss: 0.4875 - acc: 0.8213 - val_loss: 0.6664 - val_acc: 0.7348
# Epoch 6/30
# 24524/24524 [==============================] - 8s 307us/sample - loss: 0.3733 - acc: 0.8732 - val_loss: 0.8342 - val_acc: 0.6826
# Epoch 7/30
# 24524/24524 [==============================] - 7s 305us/sample - loss: 0.3252 - acc: 0.8893 - val_loss: 0.7300 - val_acc: 0.7329
# Epoch 8/30
# 24524/24524 [==============================] - 8s 307us/sample - loss: 0.2685 - acc: 0.9114 - val_loss: 0.7768 - val_acc: 0.7220
# Epoch 9/30
# 24524/24524 [==============================] - 8s 308us/sample - loss: 0.2304 - acc: 0.9207 - val_loss: 1.0377 - val_acc: 0.6820
# Epoch 10/30
# 24524/24524 [==============================] - 8s 309us/sample - loss: 0.2267 - acc: 0.9193 - val_loss: 0.9687 - val_acc: 0.7114
# Epoch 11/30
# 24524/24524 [==============================] - 7s 305us/sample - loss: 0.1827 - acc: 0.9322 - val_loss: 0.8378 - val_acc: 0.7423
# Epoch 12/30
# 24524/24524 [==============================] - 8s 307us/sample - loss: 0.1479 - acc: 0.9473 - val_loss: 0.8780 - val_acc: 0.7514
# Epoch 13/30
> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 6.2880659103393555 secs
# 24512/24524 [============================>.] - ETA: 0s - loss: 0.0902 - acc: 0.9706INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(1,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(1, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(1, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f29514f0dd8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 6.702780246734619 secs
# 24524/24524 [==============================] - 32s 1ms/sample - loss: 0.0902 - acc: 0.9706
# Training Accuracy: 0.9706
# 7883/7883 [==============================] - 5s 683us/sample - loss: 0.9276 - acc: 0.7718
# Testing Accuracy: 0.7718

# %%
tf.keras.backend.clear_session()
model_4 = Sequential(name="RNN(LSTM)")
model_4.add(tf.keras.layers.Embedding(input_dim=vocab_size,
                                    output_dim=embedding_dim,
                                    input_length=max_len))
model_4.add(tf.keras.layers.LSTM(lstm_out))
model_4.add(tf.keras.layers.Dense(6, activation='softmax'))
model_4.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])
model_4.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 350, 100)          16163700
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 6)                 606
# =================================================================
# Total params: 16,244,706
# Trainable params: 16,244,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
# This address identifies the TPU we'll use when configuring TensorFlow.
TPU_WORKER_4 = 'grpc://' + os.environ['COLAB_TPU_ADDR']
tf.logging.set_verbosity(tf.logging.INFO)
tpu_model_4 = tf.contrib.tpu.keras_to_tpu_model(
    model_4,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(TPU_WORKER_4)))
tpu_model_4.summary()
# Out:
# INFO:tensorflow:Querying Tensorflow master (grpc://10.58.52.226:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 163210747117398496)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 5905865573252813668)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 472016348054502842)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 8854384023449538565)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 6493743533975228688)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 10786899567657318559)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 10367415288657682752)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 597364814785073352)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 16117282752463516890)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 10929019859124950901)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 6691775897138489461)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_input (InputLayer) (None, 350)               0
# _________________________________________________________________
# embedding (Embedding)        (None, 350, 100)          16163700
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               80400
# _________________________________________________________________
# dense (Dense)                (None, 6)                 606
# =================================================================
# Total params: 16,244,706
# Trainable params: 16,244,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
start_time = time.time()
history_4 = tpu_model_4.fit(X_train, y_train,
                        batch_size=512,
                        epochs=30,
                        class_weight=class_weight,
                        validation_data=(X_test, y_test))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Train on 24524 samples, validate on 7883 samples
# Epoch 1/30
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(64,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(64, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(64, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f294f0ba588> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 4.985076427459717 secs
# INFO:tensorflow:Setting weights on TPU model.
# INFO:tensorflow:CPU -> TPU lr: 0.0010000000474974513 {0.001}
# INFO:tensorflow:CPU -> TPU beta_1: 0.8999999761581421 {0.9}
# INFO:tensorflow:CPU -> TPU beta_2: 0.9990000128746033 {0.999}
# INFO:tensorflow:CPU -> TPU decay: 0.0 {0.0}
# WARNING:tensorflow:Cannot update non-variable config: epsilon
# WARNING:tensorflow:Cannot update non-variable config: amsgrad
# 23552/24524 [===========================>..] - ETA: 0s - loss: 1.5452 - acc: 0.3587INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(57,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(57, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(57, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f294f0ba588> [<tf.Variable 'tpu_139815535481072/Adam/iterations:0' shape=() dtype=int64>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294defca20>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dea17b8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dea14e0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294de5aa20>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294de04ac8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dd96898>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294ddbc898>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dd2cba8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dcf7320>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dc42b00>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dc0bf28>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dbd5b70>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dba2cf8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294db38438>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294dadc7f0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294daa7c88>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294da19be0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f294d9e4748>]
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 7.728378534317017 secs
# 24064/24524 [============================>.] - ETA: 0s - loss: 1.5420 - acc: 0.3593INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(64,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(64, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(64, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f294befeeb8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 7.806267023086548 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(25,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(25, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(25, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f294befeeb8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed:
30
# 24524/24524 [==============================] - 8s 321us/sample - loss: 0.3663 - acc: 0.8768 - val_loss: 0.8390 - val_acc: 0.7580
# Epoch 24/30
# 24524/24524 [==============================] - 8s 319us/sample - loss: 0.4265 - acc: 0.8478 - val_loss: 0.9310 - val_acc: 0.6822
# Epoch 25/30
# 24524/24524 [==============================] - 8s 323us/sample - loss: 0.4507 - acc: 0.8385 - val_loss: 0.8580 - val_acc: 0.7420
# Epoch 26/30
# 24524/24524 [==============================] - 8s 321us/sample - loss: 0.3795 - acc: 0.8658 - val_loss: 0.7883 - val_acc: 0.7651
# Epoch 27/30
# 24524/24524 [==============================] - 8s 321us/sample - loss: 0.3319 - acc: 0.8880 - val_loss: 0.7652 - val_acc: 0.7801
# Epoch 28/30
# 24524/24524 [==============================] - 8s 321us/sample - loss: 0.3013 - acc: 0.9011 - val_loss: 0.7732 - val_acc: 0.7783
# Epoch 29/30
# 24524/24524 [==============================] - 8s 322us/sample - loss: 0.5028 - acc: 0.8685 - val_loss: 1.1559 - val_acc: 0.7137
# Epoch 30/30
# 24524/24524 [==============================] - 8s 321us/sample - loss: 0.4308 - acc: 0.8667 - val_loss: 0.7648 - val_acc: 0.7787
# --- 290.5652458667755 seconds ---

# %%
loss, accuracy = tpu_model_4.evaluate(X_train, y_train)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = tpu_model_4.evaluate(X_test, y_test)
print("Testing Accuracy: {:.4f}".format(accuracy))
# Out:
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(4, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(4, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f294befeeb8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 7.485368728637695 secs
# 24480/24524 [============================>.] - ETA: 0s - loss: 0.3281 - acc: 0.8911INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(1,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(1, 350), dtype=tf.float32, name='embedding_input_10'), TensorSpec(shape=(1, 6), dtype=tf.float32, name='dense_target_30')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for embedding_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f294befeeb8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 7.496472597122192 secs
# 24524/24524 [==============================] - 37s 2ms/sample - loss: 0.3280 - acc: 0.8912
# Training Accuracy: 0.8912
# 7883/7883 [==============================] - 6s 724us/sample - loss: 0.7646 - acc: 0.7787
# Testing Accuracy: 0.7787

# %%
tpu_model_2 = tf.contrib.tpu.keras_to_tpu_model(
    model_2,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(TPU_WORKER)))
tpu_model_2.summary()

# %%
start_time = time.time()
history_2 = tpu_model_2.fit(X_train, y_train,
                        batch_size=512,
                        epochs=30,
                        class_weight=class_weight,
                        validation_data=(X_test, y_test))
print("--- %s seconds ---" % (time.time() - start_time))

# %%
loss, accuracy = tpu_model_2.evaluate(X_train, y_train)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = tpu_model_2.evaluate(X_test, y_test)
print("Testing Accuracy: {:.4f}".format(accuracy))

# %%
start_time = time.time()
history_5 = tpu_model_5.fit(X_train, y_train,
                        batch_size=512,
                        epochs=30,
                        class_weight=class_weight,
                        validation_data=(X_test, y_test))
print("--- %s seconds ---" % (time.time() - start_time))

# %%
loss, accuracy = tpu_model_5.evaluate(X_train, y_train)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = tpu_model_5.evaluate(X_test, y_test)
print("Testing Accuracy: {:.4f}".format(accuracy))

# %%
plot_history(history_1)
#plot_history(history_2)
plot_history(history_3)
plot_history(history_4)
#plot_history(history_5)

# %%
history_list = [history_1, history_3, history_4]
plot_history_one_graph(history_list)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
test_one_twitter = tokenizer.texts_to_sequences(["Contemplating giving in to the iPhone bandwagon simply because #Cellcom has no new Androids #depressing #IDontWantTo"])
test_one_twitter = pad_sequences(test_one_twitter, padding='post', maxlen=max_len)

test_one_news = tokenizer.texts_to_sequences(["The legal action, filed in New York's Southern District, is against Deutsche Bank, one of Trump's lenders, and Capital One. Both banks \"have long provided business and personal banking services to Plaintiffs,\" Trump's attorneys said.\"The subpoenas were issued to harass President Donald J. Trump, to rummage through every aspect of his personal finances, his businesses, and the private information of the President and his family, and to ferret about for any material that might be used to cause him political damage. No grounds exist to establish any purpose other than a political one,\" Trump's attorneys wrote in the complaint filed late Monday."])
test_one_news = pad_sequences(test_one_news, padding='post', maxlen=max_len)

test_one_reddit = tokenizer.texts_to_sequences(["I paid a friend of mine some money to draw me a skin for Mercy I've always wanted. Yes, I know she's Swiss. No, I don't care. I wish it was a skin in game so I could ALWAYS USE IT. And against my better judgement I've posted it here to show off how good my friends art is. I hope y'all enjoy it, and if you don't, that's okay too ♥ Edit: She replied! https://www.instagram.com/jenv_arts/ and https://twitter.com/jenv_arts Enjoy everyone!"])
test_one_reddit = pad_sequences(test_one_reddit, padding='post', maxlen=max_len)

test_one_random = tokenizer.texts_to_sequences(["They dont need a product I've said it countless times there are groups that are just writing a report about analysing a data set using the exact same process we did in class Our product would be the code that cleaned and processed the data, the code that collected it, and hopefully if achievable the tensorflow program that trains a model to do something"])
test_one_random = pad_sequences(test_one_random, padding='post', maxlen=max_len)

test_one_aaaa = tokenizer.texts_to_sequences(["aaaaaaaaaaaaaaaaa aaaaaaa a aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa a aaaa aaaaaaaaaaaaaaaa aaaa aaaaaaaaaaaaaaaaaaaaaaaaa aaaaa aaaaaaaaaaaaaaaaaaaaaaa aa a aaaaaaaaaaaaaaaaa aaaaa aaaaa aaaaaaaaaaaaaaa aaa aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa a a a a aaaaaaaaaaa"])
test_one_aaaa = pad_sequences(test_one_aaaa, padding='post', maxlen=max_len)

# %%
test_one_twitter_8 = np.append(test_one_twitter, test_one_twitter, axis=0)
test_one_twitter_8 = np.append(test_one_twitter_8, test_one_twitter, axis=0)
test_one_twitter_8 = np.append(test_one_twitter_8, test_one_twitter, axis=0)
test_one_twitter_8 = np.append(test_one_twitter_8, test_one_twitter, axis=0)
test_one_twitter_8 = np.append(test_one_twitter_8, test_one_twitter, axis=0)
test_one_twitter_8 = np.append(test_one_twitter_8, test_one_twitter, axis=0)
test_one_twitter_8 = np.append(test_one_twitter_8, test_one_twitter, axis=0)

# %%
test_one_news_8 = np.append(test_one_news, test_one_news, axis=0)
test_one_news_8 = np.append(test_one_news_8, test_one_news, axis=0)
test_one_news_8 = np.append(test_one_news_8, test_one_news, axis=0)
test_one_news_8 = np.append(test_one_news_8, test_one_news, axis=0)
test_one_news_8 = np.append(test_one_news_8, test_one_news, axis=0)
test_one_news_8 = np.append(test_one_news_8, test_one_news, axis=0)
test_one_news_8 = np.append(test_one_news_8, test_one_news, axis=0)

# %%
test_one_random_8 = np.append(test_one_random, test_one_random, axis=0)
test_one_random_8 = np.append(test_one_random_8, test_one_random, axis=0)
test_one_random_8 = np.append(test_one_random_8, test_one_random, axis=0)
test_one_random_8 = np.append(test_one_random_8, test_one_random, axis=0)
test_one_random_8 = np.append(test_one_random_8, test_one_random, axis=0)
test_one_random_8 = np.append(test_one_random_8, test_one_random, axis=0)
test_one_random_8 = np.append(test_one_random_8, test_one_random, axis=0)

# %%
test_one_aaaa_8 = np.append(test_one_aaaa, test_one_aaaa, axis=0)
test_one_aaaa_8 = np.append(test_one_aaaa_8, test_one_aaaa, axis=0)
test_one_aaaa_8 = np.append(test_one_aaaa_8, test_one_aaaa, axis=0)
test_one_aaaa_8 = np.append(test_one_aaaa_8, test_one_aaaa, axis=0)
test_one_aaaa_8 = np.append(test_one_aaaa_8, test_one_aaaa, axis=0)
test_one_aaaa_8 = np.append(test_one_aaaa_8, test_one_aaaa, axis=0)
test_one_aaaa_8 = np.append(test_one_aaaa_8, test_one_aaaa, axis=0)

# %%
test_one_news_8.shape

# %%
test_one_random_8.shape

# %%
test_one_aaaa_8.shape

# %%
X_validation.shape

# %%
X_validation_resized = X_validation[:-4,:]

# %%
y_validation_resized = y_validation[:-4,:]

# %%
print(X_validation_resized.shape, y_validation_resized.shape)

# %%
prediction = tpu_model.predict(X_validation_resized)
name_labels = ''
j = 0
for i in label_encoder.classes_:
  name_labels += str(j) + " - " + i + "   "
  j += 1

# %%
confusion_matrix(
    y_validation_resized.argmax(axis=1),
    np.round(prediction).argmax(axis=1))

# %%
import seaborn as sns
fig = sns.heatmap(confusion_matrix(
    y_validation_resized.argmax(axis=1),
    np.round(prediction).argmax(axis=1)),
            annot=True,
            fmt='.5g')
plt.title(name_labels)

# %%
conf_mat = confusion_matrix(
    y_validation_resized.argmax(axis=1),
    np.round(prediction).argmax(axis=1))
labels = ['Joke', 'NYTimes', 'Negative Tweet', 'Positive Tweet', 'Spook', 'Story']
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(conf_mat, cmap=plt.cm.Blues)
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('Expected')
plt.show()

# %%
prediction = tpu_model.predict(test_one_twitter_8)
for x in np.round(prediction, decimals=3):
    print("Joke: " + str(np.format_float_positional(x[0], pad_right=3)) + " | NYTimes: " + str(np.format_float_positional(x[1], pad_right=3)) + " | Negative Tweets: " + str(np.format_float_positional(x[2], pad_right=3)) + " | Positive Tweets: " + str(np.format_float_positional(x[3], pad_right=3)) + " | Spook: " + str(np.format_float_positional(x[4], pad_right=3)) + " | Story: " + str(np.format_float_positional(x[5], pad_right=3)) + "\n")

# %%
prediction = tpu_model.predict(test_one_news_8)
for x in np.round(prediction, decimals=3):
    print("News: " + str(np.format_float_positional(x[0], pad_right=3)) + " | Reddit: " + str(np.format_float_positional(x[1], pad_right=3)) + " | Twitter: " + str(np.format_float_positional(x[2], pad_right=3)) + "\n")

# %%
prediction = tpu_model.predict(test_one_random_8)
for x in np.round(prediction, decimals=3):
    print("News: " + str(np.format_float_positional(x[0], pad_right=3)) + " | Reddit: " + str(np.format_float_positional(x[1], pad_right=3)) + " | Twitter: " + str(np.format_float_positional(x[2], pad_right=3)) + "\n")

# %%
prediction = tpu_model.predict(test_one_aaaa_8)
for x in np.round(prediction, decimals=3):
    print("News: " + str(np.format_float_positional(x[0], pad_right=3)) + " | Reddit: " + str(np.format_float_positional(x[1], pad_right=3)) + " | Twitter: " + str(np.format_float_positional(x[2], pad_right=3)) + "\n")
